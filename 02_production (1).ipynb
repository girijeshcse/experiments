# %%
#hide
# !pip install -Uqq fastbook
import fastbook
fastbook.setup_book()
# Out:
# c:\users\hp\.conda\envs\fastai\lib\site-packages\fastbook\__init__.py:18: UserWarning: Missing `graphviz` - please run `conda install fastbook`
#   except ModuleNotFoundError: warn("Missing `graphviz` - please run `conda install fastbook`")

# %%
#hide
from fastbook import *
from fastai.vision.widgets import *

# %% [markdown]
# # From Model to Production

# %% [markdown]
# ## The Practice of Deep Learning

# %% [markdown]
# ### Starting Your Project

# %% [markdown]
# ### The State of Deep Learning

# %% [markdown]
# #### Computer vision

# %% [markdown]
# #### Text (natural language processing)

# %% [markdown]
# #### Combining text and images

# %% [markdown]
# #### Tabular data

# %% [markdown]
# #### Recommendation systems

# %% [markdown]
# #### Other data types

# %% [markdown]
# ### The Drivetrain Approach

# %% [markdown]
# ## Gathering Data

# %% [markdown]
# # clean
# To download images with Bing Image Search, sign up at [Microsoft Azure](https://azure.microsoft.com/en-us/services/cognitive-services/bing-web-search-api/) for a free account. You will be given a key, which you can copy and enter in a cell as follows (replacing 'XXX' with your key and executing it):

# %%
import os
#key = os.environ.get('AZURE_SEARCH_KEY', 'XXX')

# %%
#search_images_bing
def search_images_ddg(term, max_images=200):
    "Search for `term` with DuckDuckGo and return a unique urls of about `max_images` images"
    assert max_images<1000
    url = 'https://duckduckgo.com/'
    res = urlread(url,data={'q':term}, decode=False).decode()
    searchObj = re.search(r'vqd=([\d-]+)\&', res)
    assert searchObj
    requestUrl = url + 'i.js'
    params = dict(l='us-en', o='json', q=term, vqd=searchObj.group(1), f=',,,', p='1', v7exp='a')
    urls,data = set(),{'next':1}
    while len(urls)<max_images and 'next' in data:
        try:
            data = urljson(requestUrl,data=params)
            urls.update(L(data['results']).itemgot('image'))
            requestUrl = url + data['next']
        except (URLError,HTTPError): pass
        time.sleep(0.2)
    return L(urls)

# %%
results = search_images_ddg('grizzly bear', max_images=100)

len(results)
# Out:
# 100

# %%
bear_types = 'grizzly','black','teddy'
path = Path('bears')

# %%
from tqdm import tqdm
if not path.exists():
    path.mkdir()
    for o in tqdm(bear_types):
        dest = (path/o)
        dest.mkdir(exist_ok=True)
        results = search_images_ddg( f'{o} bear', max_images=100)
        download_images(dest, urls=results)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 3/3 [01:56<00:00, 38.99s/it]

# %%
fns = get_image_files(path)
fns
# Out:
# (#263) [Path('bears/black/00000001.jpg'),Path('bears/black/00000002.jpg'),Path('bears/black/00000003.jpg'),Path('bears/black/00000004.jpg'),Path('bears/black/00000005.jpg'),Path('bears/black/00000006.jpg'),Path('bears/black/00000007.jpg'),Path('bears/black/00000008.jpeg'),Path('bears/black/00000009.jpg'),Path('bears/black/00000010.jpg')...]

# %%
failed = verify_images(fns)
failed
# Out:
# (#7) [Path('bears/black/00000014.jpg'),Path('bears/grizzly/00000054.jpg'),Path('bears/grizzly/00000063.png'),Path('bears/grizzly/00000099.jpg'),Path('bears/teddy/00000045.jpg'),Path('bears/teddy/00000054.jpg'),Path('bears/teddy/00000090.jpg')]

# %%
failed.map(Path.unlink);

# %% [markdown]
# ### Sidebar: Getting Help in Jupyter Notebooks

# %% [markdown]
# ### End sidebar

# %% [markdown]
# ## From Data to DataLoaders

# %%
bears = DataBlock(
    blocks=(ImageBlock, CategoryBlock), 
    get_items=get_image_files, 
    splitter=RandomSplitter(valid_pct=0.2, seed=42),
    get_y=parent_label,
    item_tfms=Resize(128))

# %%
dls = bears.dataloaders(path)
# Out:
# Due to IPython and Windows limitation, python multiprocessing isn't available now.
# So `number_workers` is changed to 0 to avoid getting stuck

# %%
dls.valid.show_batch(max_n=4, nrows=1)

# %%
bears = bears.new(item_tfms=Resize(128, ResizeMethod.Squish))
dls = bears.dataloaders(path)
dls.valid.show_batch(max_n=4, nrows=1)
# Out:
# Due to IPython and Windows limitation, python multiprocessing isn't available now.
# So `number_workers` is changed to 0 to avoid getting stuck

# %%
bears = bears.new(item_tfms=Resize(128, ResizeMethod.Pad, pad_mode='zeros'))
dls = bears.dataloaders(path)
dls.valid.show_batch(max_n=4, nrows=1)
# Out:
# Due to IPython and Windows limitation, python multiprocessing isn't available now.
# So `number_workers` is changed to 0 to avoid getting stuck

# %%
bears = bears.new(item_tfms=RandomResizedCrop(128, min_scale=0.3))
dls = bears.dataloaders(path)
dls.train.show_batch(max_n=4, nrows=1, unique=True)
# Out:
# Due to IPython and Windows limitation, python multiprocessing isn't available now.
# So `number_workers` is changed to 0 to avoid getting stuck

# %% [markdown]
# ### Data Augmentation

# %%
bears = bears.new(item_tfms=Resize(128), batch_tfms=aug_transforms(mult=2))
dls = bears.dataloaders(path)
dls.train.show_batch(max_n=8, nrows=2, unique=True)
# Out:
# Due to IPython and Windows limitation, python multiprocessing isn't available now.
# So `number_workers` is changed to 0 to avoid getting stuck
# c:\users\hp\.conda\envs\fastai\lib\site-packages\torch\_tensor.py:1023: UserWarning: torch.solve is deprecated in favor of torch.linalg.solveand will be removed in a future PyTorch release.
# torch.linalg.solve has its arguments reversed and does not return the LU factorization.
# To get the LU factorization see torch.lu, which can be used with torch.lu_solve or torch.lu_unpack.
# X = torch.solve(B, A).solution
# should be replaced with
# X = torch.linalg.solve(A, B) (Triggered internally at  ..\aten\src\ATen\native\BatchLinearAlgebra.cpp:760.)
#   ret = func(*args, **kwargs)

# %% [markdown]
# ## Training Your Model, and Using It to Clean Your Data

# %%
bears = bears.new(
    item_tfms=RandomResizedCrop(224, min_scale=0.5),
    batch_tfms=aug_transforms())
dls = bears.dataloaders(path)
# Out:
# Due to IPython and Windows limitation, python multiprocessing isn't available now.
# So `number_workers` is changed to 0 to avoid getting stuck

# %%
learn = cnn_learner(dls, resnet18, metrics=error_rate)
learn.fine_tune(4)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to C:\Users\hp/.cache\torch\hub\checkpoints\resnet18-f37072fd.pth
#   0%|          | 0.00/44.7M [00:00<?, ?B/s]
# c:\users\hp\.conda\envs\fastai\lib\site-packages\torch\nn\functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  ..\c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.633922</td>
#       <td>0.276959</td>
#       <td>0.137255</td>
#       <td>00:37</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.386377</td>
#       <td>0.076674</td>
#       <td>0.039216</td>
#       <td>00:46</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.213136</td>
#       <td>0.043766</td>
#       <td>0.019608</td>
#       <td>00:43</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.148969</td>
#       <td>0.026570</td>
#       <td>0.019608</td>
#       <td>00:44</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.112818</td>
#       <td>0.017307</td>
#       <td>0.000000</td>
#       <td>00:43</td>
#     </tr>
#   </tbody>
# </table>

# %%
interp = ClassificationInterpretation.from_learner(learn)
interp.plot_confusion_matrix()

# %%
interp.plot_top_losses(5, nrows=1)

# %%
cleaner = ImageClassifierCleaner(learn)
cleaner
# Out:
# VBox(children=(Dropdown(options=('black', 'grizzly', 'teddy'), value='black'), Dropdown(options=('Train', 'Val…

# %%
#hide
# for idx in cleaner.delete(): cleaner.fns[idx].unlink()
# for idx,cat in cleaner.change(): shutil.move(str(cleaner.fns[idx]), path/cat)

# %% [markdown]
# ## Turning Your Model into an Online Application

# %% [markdown]
# ### Using the Model for Inference

# %%
learn.export()

# %%
path = Path()
path.ls(file_exts='.pkl')
# Out:
# (#1) [Path('export.pkl')]

# %%
learn_inf = load_learner(path/'export.pkl')

# %%
learn_inf.predict('../images/grizzly.jpg')
# Out:
# ('grizzly', tensor(1), tensor([1.3406e-04, 9.9986e-01, 8.9028e-06]))

# %%
learn_inf.dls.vocab
# Out:
# ['black', 'grizzly', 'teddy']

# %% [markdown]
# ### Creating a Notebook App from the Model

# %%
btn_upload = widgets.FileUpload()
btn_upload
# Out:
# FileUpload(value={}, description='Upload')

# %%
#hide
# For the book, we can't actually click an upload button, so we fake it
btn_upload = SimpleNamespace(data = ['../images/grizzly.jpg'])

# %%
img = PILImage.create(btn_upload.data[-1])

# %%
out_pl = widgets.Output()
out_pl.clear_output()
with out_pl: display(img.to_thumb(128,128))
out_pl
# Out:
# Output()

# %%
pred,pred_idx,probs = learn_inf.predict(img)

# %%
lbl_pred = widgets.Label()
lbl_pred.value = f'Prediction: {pred}; Probability: {probs[pred_idx]:.04f}'
lbl_pred
# Out:
# Label(value='Prediction: grizzly; Probability: 0.9999')

# %%
btn_run = widgets.Button(description='Classify')
btn_run
# Out:
# Button(description='Classify', style=ButtonStyle())

# %%
def on_click_classify(change):
    img = PILImage.create(btn_upload.data[-1])
    out_pl.clear_output()
    with out_pl: display(img.to_thumb(128,128))
    pred,pred_idx,probs = learn_inf.predict(img)
    lbl_pred.value = f'Prediction: {pred}; Probability: {probs[pred_idx]:.04f}'

btn_run.on_click(on_click_classify)

# %%
#hide
#Putting back btn_upload to a widget for next cell
btn_upload = widgets.FileUpload()

# %%
VBox([widgets.Label('Select your bear!'), 
      btn_upload, btn_run, out_pl, lbl_pred])
# Out:
# VBox(children=(Label(value='Select your bear!'), FileUpload(value={}, description='Upload'), Button(descriptio…

# %% [markdown]
# ### Turning Your Notebook into a Real App

# %%
#hide
# !pip install voila
# !jupyter serverextension enable --sys-prefix voila
# Out:
# Collecting voila
#   Downloading voila-0.2.10-py3-none-any.whl (1.6 MB)
# Collecting nbconvert<7,>=6.0.0
#   Using cached nbconvert-6.0.7-py3-none-any.whl (552 kB)
# Requirement already satisfied: jupyter-client<7,>=6.1.3 in c:\users\hp\.conda\envs\fastai\lib\site-packages (from voila) (6.1.12)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# nbdev 1.1.14 requires nbconvert<6, but you have nbconvert 6.0.7 which is incompatible.
# Collecting jupyter-server<2.0.0,>=0.3.0
#   Downloading jupyter_server-1.9.0-py3-none-any.whl (389 kB)
# Collecting nbclient<0.6,>=0.4.0
#   Using cached nbclient-0.5.3-py3-none-any.whl (82 kB)
# Requirement already satisfied: traitlets in c:\users\hp\.conda\envs\fastai\lib\site-packages (from jupyter-client<7,>=6.1.3->voila) (4.3.3)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\hp\.conda\envs\fastai\lib\site-packages (from jupyter-client<7,>=6.1.3->voila) (2.8.1)
# Requirement already satisfied: pyzmq>=13 in c:\users\hp\.conda\envs\fastai\lib\site-packages (from jupyter-client<7,>=6.1.3->voila) (22.1.0)
# Requirement already satisfied: jupyter-core>=4.6.0 in c:\users\hp\.conda\envs\fastai\lib\site-packages (from jupyter-client<7,>=6.1.3->voila) (4.7.1)
# Requirement already satisfied: tornado>=4.1 in c:\users\hp\.conda\envs\fastai\lib\site-packages (from jupyter-client<7,>=6.1.3->voila) (6.1)
# Requirement already satisfied: pywin32>=1.0 in c:\users\hp\.conda\envs\fastai\lib\site-packages (from jupyter-core>=4.6.0->jupyter-client<7,>=6.1.3->voila) (301)
# Requirement already satisfied: nbformat in c:\users\hp\.conda\envs\fastai\lib\site-packages (from jupyter-server<2.0.0,>=0.3.0->voila) (5.1.3)
# Collecting websocket-client
#   Using cached websocket_client-1.1.0-py2.py3-none-any.whl (68 kB)
# Requirement already satisfied: argon2-cffi in c:\users\hp\.conda\envs\fastai\lib\site-packages (from jupyter-server<2.0.0,>=0.3.0->voila) (20.1.0)
# Requirement already satisfied: Send2Trash in c:\users\hp\.conda\envs\fastai\lib\site-packages (from jupyter-server<2.0.0,>=0.3.0->voila) (1.7.1)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\hp\.conda\envs\fastai\lib\site-packages (from jupyter-server<2.0.0,>=0.3.0->voila) (0.10.1)
# Requirement already satisfied: prometheus-client in c:\users\hp\.conda\envs\fastai\lib\site-packages (from jupyter-server<2.0.0,>=0.3.0->voila) (0.11.0)
# Collecting requests-unixsocket
#   Downloading requests_unixsocket-0.2.0-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: jinja2 in c:\users\hp\.conda\envs\fastai\lib\site-packages (from jupyter-server<2.0.0,>=0.3.0->voila) (3.0.1)
# Collecting anyio<4,>=3.1.0
#   Downloading anyio-3.2.1-py3-none-any.whl (75 kB)
# Requirement already satisfied: ipython-genutils in c:\users\hp\.conda\envs\fastai\lib\site-packages (from jupyter-server<2.0.0,>=0.3.0->voila) (0.2.0)
# Requirement already satisfied: idna>=2.8 in c:\users\hp\.conda\envs\fastai\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server<2.0.0,>=0.3.0->voila) (2.10)
# Collecting async-generator
#   Using cached async_generator-1.10-py3-none-any.whl (18 kB)
# Collecting sniffio>=1.1
#   Downloading sniffio-1.2.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: typing-extensions in c:\users\hp\.conda\envs\fastai\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server<2.0.0,>=0.3.0->voila) (3.10.0.0)
# Requirement already satisfied: dataclasses in c:\users\hp\.conda\envs\fastai\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server<2.0.0,>=0.3.0->voila) (0.8)
# Collecting nest-asyncio
#   Using cached nest_asyncio-1.5.1-py3-none-any.whl (5.0 kB)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\hp\.conda\envs\fastai\lib\site-packages (from nbconvert<7,>=6.0.0->voila) (1.4.3)
# Requirement already satisfied: bleach in c:\users\hp\.conda\envs\fastai\lib\site-packages (from nbconvert<7,>=6.0.0->voila) (3.3.0)
# Requirement already satisfied: defusedxml in c:\users\hp\.conda\envs\fastai\lib\site-packages (from nbconvert<7,>=6.0.0->voila) (0.7.1)
# Collecting jupyterlab-pygments
#   Using cached jupyterlab_pygments-0.1.2-py2.py3-none-any.whl (4.6 kB)
# Requirement already satisfied: testpath in c:\users\hp\.conda\envs\fastai\lib\site-packages (from nbconvert<7,>=6.0.0->voila) (0.5.0)
# Requirement already satisfied: pygments>=2.4.1 in c:\users\hp\.conda\envs\fastai\lib\site-packages (from nbconvert<7,>=6.0.0->voila) (2.9.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\hp\.conda\envs\fastai\lib\site-packages (from nbconvert<7,>=6.0.0->voila) (0.8.4)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\hp\.conda\envs\fastai\lib\site-packages (from nbconvert<7,>=6.0.0->voila) (0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\hp\.conda\envs\fastai\lib\site-packages (from jinja2->jupyter-server<2.0.0,>=0.3.0->voila) (2.0.1)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\users\hp\.conda\envs\fastai\lib\site-packages (from nbformat->jupyter-server<2.0.0,>=0.3.0->voila) (3.2.0)
# Requirement already satisfied: importlib-metadata in c:\users\hp\.conda\envs\fastai\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->jupyter-server<2.0.0,>=0.3.0->voila) (4.5.0)
# Requirement already satisfied: six>=1.11.0 in c:\users\hp\.conda\envs\fastai\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->jupyter-server<2.0.0,>=0.3.0->voila) (1.16.0)
# Requirement already satisfied: setuptools in c:\users\hp\.conda\envs\fastai\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->jupyter-server<2.0.0,>=0.3.0->voila) (52.0.0.post20210125)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\hp\.conda\envs\fastai\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->jupyter-server<2.0.0,>=0.3.0->voila) (21.2.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\hp\.conda\envs\fastai\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->jupyter-server<2.0.0,>=0.3.0->voila) (0.17.3)
# Requirement already satisfied: contextvars>=2.1 in c:\users\hp\.conda\envs\fastai\lib\site-packages (from sniffio>=1.1->anyio<4,>=3.1.0->jupyter-server<2.0.0,>=0.3.0->voila) (2.4)
# Requirement already satisfied: immutables>=0.9 in c:\users\hp\.conda\envs\fastai\lib\site-packages (from contextvars>=2.1->sniffio>=1.1->anyio<4,>=3.1.0->jupyter-server<2.0.0,>=0.3.0->voila) (0.15)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\hp\.conda\envs\fastai\lib\site-packages (from terminado>=0.8.3->jupyter-server<2.0.0,>=0.3.0->voila) (1.1.3)
# Requirement already satisfied: decorator in c:\users\hp\.conda\envs\fastai\lib\site-packages (from traitlets->jupyter-client<7,>=6.1.3->voila) (5.0.9)
# Requirement already satisfied: cffi>=1.0.0 in c:\users\hp\.conda\envs\fastai\lib\site-packages (from argon2-cffi->jupyter-server<2.0.0,>=0.3.0->voila) (1.14.5)
# Requirement already satisfied: pycparser in c:\users\hp\.conda\envs\fastai\lib\site-packages (from cffi>=1.0.0->argon2-cffi->jupyter-server<2.0.0,>=0.3.0->voila) (2.20)
# Requirement already satisfied: packaging in c:\users\hp\.conda\envs\fastai\lib\site-packages (from bleach->nbconvert<7,>=6.0.0->voila) (20.9)
# Requirement already satisfied: webencodings in c:\users\hp\.conda\envs\fastai\lib\site-packages (from bleach->nbconvert<7,>=6.0.0->voila) (0.5.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\hp\.conda\envs\fastai\lib\site-packages (from importlib-metadata->jsonschema!=2.5.0,>=2.4->nbformat->jupyter-server<2.0.0,>=0.3.0->voila) (3.4.1)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\hp\.conda\envs\fastai\lib\site-packages (from packaging->bleach->nbconvert<7,>=6.0.0->voila) (2.4.7)
# Requirement already satisfied: requests>=1.1 in c:\users\hp\.conda\envs\fastai\lib\site-packages (from requests-unixsocket->jupyter-server<2.0.0,>=0.3.0->voila) (2.25.1)
# Requirement already satisfied: urllib3>=1.8 in c:\users\hp\.conda\envs\fastai\lib\site-packages (from requests-unixsocket->jupyter-server<2.0.0,>=0.3.0->voila) (1.26.6)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hp\.conda\envs\fastai\lib\site-packages (from requests>=1.1->requests-unixsocket->jupyter-server<2.0.0,>=0.3.0->voila) (2021.5.30)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\hp\.conda\envs\fastai\lib\site-packages (from requests>=1.1->requests-unixsocket->jupyter-server<2.0.0,>=0.3.0->voila) (4.0.0)
# Installing collected packages: nest-asyncio, async-generator, sniffio, nbclient, jupyterlab-pygments, websocket-client, requests-unixsocket, nbconvert, anyio, jupyter-server, voila
#   Attempting uninstall: nbconvert
#     Found existing installation: nbconvert 5.6.1
#     Uninstalling nbconvert-5.6.1:
#       Successfully uninstalled nbconvert-5.6.1
# Successfully installed anyio-3.2.1 async-generator-1.10 jupyter-server-1.9.0 jupyterlab-pygments-0.1.2 nbclient-0.5.3 nbconvert-6.0.7 nest-asyncio-1.5.1 requests-unixsocket-0.2.0 sniffio-1.2.0 voila-0.2.10 websocket-client-1.1.0
# Enabling: voila
# - Writing config: c:\users\hp\.conda\envs\fastai\etc\jupyter
#     - Validating...
#       voila 0.2.10 ok

# %% [markdown]
# ### Deploying your app

# %% [markdown]
# ## How to Avoid Disaster

# %% [markdown]
# ### Unforeseen Consequences and Feedback Loops

# %% [markdown]
# ## Get Writing!

# %% [markdown]
# ## Questionnaire

# %% [markdown]
# 1. Provide an example of where the bear classification model might work poorly in production, due to structural or style differences in the training data.
# 1. Where do text models currently have a major deficiency?
# 1. What are possible negative societal implications of text generation models?
# 1. In situations where a model might make mistakes, and those mistakes could be harmful, what is a good alternative to automating a process?
# 1. What kind of tabular data is deep learning particularly good at?
# 1. What's a key downside of directly using a deep learning model for recommendation systems?
# 1. What are the steps of the Drivetrain Approach?
# 1. How do the steps of the Drivetrain Approach map to a recommendation system?
# 1. Create an image recognition model using data you curate, and deploy it on the web.
# 1. What is `DataLoaders`?
# 1. What four things do we need to tell fastai to create `DataLoaders`?
# 1. What does the `splitter` parameter to `DataBlock` do?
# 1. How do we ensure a random split always gives the same validation set?
# 1. What letters are often used to signify the independent and dependent variables?
# 1. What's the difference between the crop, pad, and squish resize approaches? When might you choose one over the others?
# 1. What is data augmentation? Why is it needed?
# 1. What is the difference between `item_tfms` and `batch_tfms`?
# 1. What is a confusion matrix?
# 1. What does `export` save?
# 1. What is it called when we use a model for getting predictions, instead of training?
# 1. What are IPython widgets?
# 1. When might you want to use CPU for deployment? When might GPU be better?
# 1. What are the downsides of deploying your app to a server, instead of to a client (or edge) device such as a phone or PC?
# 1. What are three examples of problems that could occur when rolling out a bear warning system in practice?
# 1. What is "out-of-domain data"?
# 1. What is "domain shift"?
# 1. What are the three steps in the deployment process?

# %% [markdown]
# ### Further Research

# %% [markdown]
# 1. Consider how the Drivetrain Approach maps to a project or problem you're interested in.
# 1. When might it be best to avoid certain types of data augmentation?
# 1. For a project you're interested in applying deep learning to, consider the thought experiment "What would happen if it went really, really well?"
# 1. Start a blog, and write your first blog post. For instance, write about what you think deep learning might be useful for in a domain you're interested in.
